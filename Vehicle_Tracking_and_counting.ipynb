# %% [markdown]
# # Vehicle Detection and Counting Model

# %% [markdown]
# #**Clone the Github Repo**

# %%
# !git clone https://github.com/MuhammadMoinFaisal/YOLOv8-DeepSORT-Object-Tracking.git
# Out:
# Cloning into 'YOLOv8-DeepSORT-Object-Tracking'...
# remote: Enumerating objects: 403, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 403 (delta 21), reused 19 (delta 19), pack-reused 370 (from 1)
# Receiving objects: 100% (403/403), 77.99 MiB | 10.35 MiB/s, done.
# Resolving deltas: 100% (206/206), done.

# %% [markdown]
# ##Setting the Current Directory

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking

# %% [markdown]
# ##Install all the Dependencies

# %%
# !pip install -e '.[dev]'
# Out:
# Obtaining file:///content/YOLOv8-DeepSORT-Object-Tracking
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.3
#     Uninstalling ultralytics-8.0.3:
#       Successfully uninstalled ultralytics-8.0.3
#   Running setup.py develop for ultralytics
# ...

# %% [markdown]
# ##Moving to the Required Directory

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %% [markdown]
# ##To implement the DeepSORT tracking, downloading the required files

# %%
# !gdown "https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t
# To: /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/deep_sort_pytorch.zip
# 100% 43.1M/43.1M [00:00<00:00, 200MB/s]

# %% [markdown]
# ##Unzipping the DeepSORT Files

# %%
# !unzip 'deep_sort_pytorch.zip'
# Out:
# Archive:  deep_sort_pytorch.zip
# replace deep_sort_pytorch/.gitignore? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: deep_sort_pytorch/.gitignore
# replace deep_sort_pytorch/configs/deep_sort.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: deep_sort_pytorch/configs/deep_sort.yaml
# replace deep_sort_pytorch/deep_sort/__init__.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: deep_sort_pytorch/deep_sort/__init__.py
# replace deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-310.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-310.pyc
# replace deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-37.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-37.pyc
# replace deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-38.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# ...

# %% [markdown]
# ##Download a Sample Video for Testing from Google Drive

# %%
# !gdown https://drive.google.com/uc?id=1_kt1alzcLRVxet-Drx0mt_KFSd3vrtHU
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_kt1alzcLRVxet-Drx0mt_KFSd3vrtHU
# To: /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/test1.mp4
# 100% 6.11M/6.11M [00:00<00:00, 72.8MB/s]

# %% [markdown]
# ##Lets Run the Script

# %%
# !gdown "https://drive.google.com/uc?id=1QZijehoi66eAhNAsy78SnOqatBWfckjl&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1QZijehoi66eAhNAsy78SnOqatBWfckjl&confirm=t
# To: /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/predict.py
# 100% 12.9k/12.9k [00:00<00:00, 39.3MB/s]

# %%
import os
import re

def fix_all_numpy_issues(directory):
    replacements = {
        r'dtype=np\.int\b': 'dtype=int',
        r'dtype=np\.float\b': 'dtype=float',
        r'\.astype\(np\.int\)': '.astype(int)',
        r'\.astype\(np\.float\)': '.astype(float)',
        r'np\.int\b': 'int',
        r'np\.float\b': 'float'
    }

    fixed_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.py'):
                filepath = os.path.join(root, file)
                try:
                    with open(filepath, 'r') as f:
                        content = f.read()

                    original_content = content
                    for pattern, replacement in replacements.items():
                        content = re.sub(pattern, replacement, content)

                    if content != original_content:
                        with open(filepath, 'w') as f:
                            f.write(content)
                        fixed_files.append(filepath)
                        print(f"Fixed: {filepath}")

                except Exception as e:
                    print(f"Error processing {filepath}: {e}")

    print(f"\nFixed {len(fixed_files)} files total")

# Run the comprehensive fix
fix_all_numpy_issues('/content/YOLOv8-DeepSORT-Object-Tracking/')
# Out:
# Fixed: /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/deep_sort_pytorch/deep_sort/deep_sort.py
#
# Fixed 1 files total

# %%
# !python predict.py model=yolov8m.pt source="/content/video.mp4"
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (3658/8655) /content/video.mp4: 640x608 3 persons, 3 motorcycles, 2 traffic lights, 32.7ms
# video 1/1 (3659/8655) /content/video.mp4: 640x608 3 persons, 3 motorcycles, 2 traffic lights, 32.7ms
# video 1/1 (3660/8655) /content/video.mp4: 640x608 4 persons, 3 motorcycles, 2 traffic lights, 32.7ms
# video 1/1 (3661/8655) /content/video.mp4: 640x608 4 persons, 3 motorcycles, 2 traffic lights, 36.6ms
# video 1/1 (3662/8655) /content/video.mp4: 640x608 6 persons, 3 motorcycles, 2 traffic lights, 37.0ms
# video 1/1 (3663/8655) /content/video.mp4: 640x608 5 persons, 3 motorcycles, 2 traffic lights, 38.5ms
# video 1/1 (3664/8655) /content/video.mp4: 640x608 5 persons, 3 motorcycles, 2 traffic lights, 37.0ms
# video 1/1 (3665/8655) /content/video.mp4: 640x608 6 persons, 3 motorcycles, 2 traffic lights, 37.2ms
# video 1/1 (3666/8655) /content/video.mp4: 640x608 5 persons, 3 motorcycles, 2 traffic lights, 37.0ms
# ...

# %%
# Out:
# rm: cannot remove '/content/result_compressed.mp4': No such file or directory

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-78c2bbd3e3b1> in <cell line: 0>()
#      12
#      13 # Show video
# ---> 14 mp4 = open(compressed_path,'rb').read()
#      15 data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
#      16 HTML("""
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/result_compressed.mp4'
